# %%
# !pip install openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 1.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd

# %%
data = [
    ["Adobe, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Advance Auto Parts, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["Advanced Micro Devices, Inc.", "Semiconductors", "United States and Canada", "", "", "✓"],
    ["AGCO Corp.", "Machinery", "United States and Canada", "", "", "✓"],
    ["Agilent Technologies, Inc.", "Pharmaceuticals", "United States and Canada", "", "✓", "✓"],
    ["Air Products & Chemicals, Inc.", "Chemicals", "United States and Canada", "", "✓", "✓"],
    ["Akamai Technologies, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Altus Group Ltd.", "Real Estate", "United States and Canada", "", "✓", "✓"],
    ["Amdocs Ltd.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["American Homes 4 Rent", "Real Estate", "United States and Canada", "", "✓", ""],
    ["American Tire Distributors, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["American Tower Corp.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Annaly Capital Management, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Applied Materials, Inc.", "Semiconductors", "United States and Canada", "", "✓", "✓"],
    ["AptarGroup, Inc.", "Containers & Packaging", "United States and Canada", "", "✓", ""],
    ["Arrow Electronics, Inc.", "Technology Hardware", "United States and Canada", "", "✓", "✓"],
    ["Automatic Data Processing, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["AutoNation, Inc.", "Retailing", "United States and Canada", "", "✓", ""],
    ["AutoZone, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["AvalonBay Communities, Inc.", "Real Estate", "United States and Canada", "", "✓", "✓"],
    ["Avantor, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Avis Budget Group, Inc.", "Transportation", "United States and Canada", "", "✓", "✓"],
    ["Avnet, Inc.", "Technology Hardware", "United States and Canada", "", "✓", "✓"],
    ["Azenta, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Ball Corp.", "Containers & Packaging", "United States and Canada", "", "✓", ""],
    ["Bio-Rad Laboratories, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Bio-Techne Corp.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["BorgWarner, Inc.", "Auto Components", "United States and Canada", "", "✓", "✓"],
    ["Boston Properties, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Brixmor Property Group, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["BRP, Inc.", "Consumer Durables", "United States and Canada", "", "✓", ""],
    ["Bruce Power LP", "Utilities", "United States and Canada", "", "✓", "✓"],
    ["Cadence Design Systems, Inc.", "Software & Services", "United States and Canada", "", "✓", "✓"],
    ["Canadian National Railway Co.", "Transportation", "United States and Canada", "", "", "✓"],
    ["Cardinal Health, Inc.", "Healthcare", "United States and Canada", "", "", "✓"],
    ["CarMax, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["Carter's, Inc.", "Retailing", "United States and Canada", "", "✓", ""],
    ["CBRE Group, Inc.", "Real Estate", "United States and Canada", "", "✓", "✓"],
    ["CDW Corp.", "Technology Hardware", "United States and Canada", "", "✓", "✓"],
    ["Celestica, Inc.", "Technology Hardware", "United States and Canada", "", "✓", "✓"],
    ["Cencora, Inc.", "Healthcare", "United States and Canada", "", "✓", "✓"],
    ["Charles River Laboratories International, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Choice Properties Real Estate Investment Trust", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Cirrus Logic, Inc.", "Semiconductors", "United States and Canada", "", "", "✓"],
    ["Cisco Systems, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Cogeco Communications, Inc.", "Media", "United States and Canada", "", "✓", "✓"],
    ["Cognex Corp.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Cognizant Technology Solutions Corp.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Colliers International Group, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Convergent Energy & Power, Inc.", "Utilities", "United States and Canada", "", "✓", "✓"],
    ["Cousins Properties, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Crown Castle, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Crown Holdings, Inc.", "Containers & Packaging", "United States and Canada", "", "✓", "✓"],
    ["Danaher Corp.", "Pharmaceuticals", "United States and Canada", "", "✓", "✓"],
    ["Darling Ingredients, Inc.", "Food Products", "United States and Canada", "", "", "✓"],
    ["Dentsply Sirona, Inc.", "Healthcare", "United States and Canada", "", "", "✓"],
    ["Digital Realty Trust, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Dolby Laboratories, Inc.", "Media", "United States and Canada", "", "✓", ""],
    ["Dream Industrial Real Estate Investment Trust", "Real Estate", "United States and Canada", "", "✓", ""],
    ["DXC Technology Co.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Ecolab, Inc.", "Chemicals", "United States and Canada", "", "", "✓"],
    ["Electronic Arts, Inc.", "Software & Services", "United States and Canada", "", "✓", "✓"],
    ["Elevance Health, Inc.", "Healthcare", "United States and Canada", "", "✓", "✓"],
    ["Enbridge, Inc.", "Refiners & Pipelines", "United States and Canada", "", "", "✓"],
    ["Enterprise Products Partners LP", "Refiners & Pipelines", "United States and Canada", "", "", "✓"],
    ["Equity Residential", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Essex Property Trust, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Finning International, Inc.", "Traders & Distributors", "United States and Canada", "", "", "✓"],
    ["First Capital Real Estate Investment Trust", "Real Estate", "United States and Canada", "", "✓", ""],
    ["First West Credit Union", "Banks", "United States and Canada", "", "✓", "✓"],
    ["Flex Ltd.", "Technology Hardware", "United States and Canada", "", "✓", "✓"],
    ["Fox Corp.", "Media", "United States and Canada", "", "✓", ""],
    ["Franco-Nevada Corp.", "Precious Metals", "United States and Canada", "", "✓", "✓"],
    ["Freehold Royalties Ltd.", "Oil & Gas Producers", "United States and Canada", "", "✓", "✓"],
    ["Frontdoor, Inc.", "Consumer Services", "United States and Canada", "", "✓", "✓"],
    ["General Mills, Inc.", "Food Products", "United States and Canada", "", "", "✓"],
    ["Genuine Parts Co.", "Retailing", "United States and Canada", "", "✓", ""],
    ["Gibson Energy, Inc.", "Refiners & Pipelines", "United States and Canada", "", "", "✓"],
    ["Gildan Activewear, Inc.", "Textiles & Apparel", "United States and Canada", "", "✓", "✓"],
    ["GLOBALFOUNDRIES, Inc.", "Semiconductors", "United States and Canada", "", "", "✓"],
    ["Graham Packaging Co., Inc.", "Containers & Packaging", "United States and Canada", "", "✓", "✓"],
    ["Granite Real Estate Investment Trust", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Guidewire Software, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Hasbro, Inc.", "Consumer Durables", "United States and Canada", "", "✓", "✓"],
    ["Healthpeak Properties, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Henry Schein, Inc.", "Healthcare", "United States and Canada", "", "", "✓"],
    ["Hewlett Packard Enterprise Co.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Highwoods Properties, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Host Hotels & Resorts, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["HP, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Hydro One Ltd.", "Utilities", "United States and Canada", "", "", "✓"],
    ["IGM Financial, Inc.", "Diversified Financials", "United States and Canada", "", "✓", "✓"],
    ["Illumina, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Ingersoll Rand, Inc.", "Machinery", "United States and Canada", "", "✓", "✓"],
    ["Inter-American Development Bank", "Banks", "United States and Canada", "✓", "✓", "✓"],
    ["Inter-American Investment Corp.", "Banks", "United States and Canada", "", "✓", "✓"],
    ["International Bank for Reconstruction & Development", "Banks", "United States and Canada", "", "✓", "✓"],
    ["International Business Machines Corp.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["International Finance Corp.", "Banks", "United States and Canada", "", "✓", "✓"],
    ["Interpublic Group of Cos., Inc.", "Media", "United States and Canada", "", "✓", "✓"],
    ["IPG Photonics Corp.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Iron Mountain, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["J.B. Hunt Transport Services, Inc.", "Transportation", "United States and Canada", "", "", "✓"],
    ["Jabil, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Jacobs Engineering Group, Inc.", "Construction & Engineering", "United States and Canada", "", "", "✓"],
    ["Jones Lang LaSalle, Inc.", "Real Estate", "United States and Canada", "✓", "✓", "✓"],
    ["Keysight Technologies, Inc.", "Technology Hardware", "United States and Canada", "✓", "✓", "✓"],
    ["Killam Apartment REIT", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Kilroy Realty Corp.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Kimco Realty Corp.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Kinaxis, Inc.", "Software & Services", "United States and Canada", "", "✓", "✓"],
    ["Kinder Morgan, Inc.", "Refiners & Pipelines", "United States and Canada", "", "", "✓"],
    ["L3Harris Technologies, Inc.", "Aerospace & Defense", "United States and Canada", "", "", "✓"],
    ["Labrador Iron Ore Royalty Corp.", "Steel", "United States and Canada", "", "", "✓"],
    ["Lam Research Corp.", "Semiconductors", "United States and Canada", "", "✓", "✓"],
    ["Lear Corp.", "Auto Components", "United States and Canada", "", "✓", ""],
    ["Life Storage, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Lithia Motors, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["LKQ Corp.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["Lowe's Companies, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["Lumentum Holdings, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["ManpowerGroup, Inc.", "Commercial Services", "United States and Canada", "", "✓", ""],
    ["Maravai Lifesciences Holdings, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Massachusetts Mutual Life Insurance Co.", "Insurance", "United States and Canada", "", "", "✓"],
    ["McKesson Corp.", "Healthcare", "United States and Canada", "", "", "✓"],
    ["Mettler-Toledo International, Inc.", "Pharmaceuticals", "United States and Canada", "", "✓", "✓"],
    ["Microsoft Corp.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Mid-America Apartment Communities, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["MKS Instruments, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Mohawk Industries, Inc.", "Consumer Durables", "United States and Canada", "", "✓", ""],
    ["Motorola Solutions, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Nasdaq, Inc.", "Diversified Financials", "United States and Canada", "", "✓", "✓"],
    ["National Instruments Corp.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["News Corp.", "Media", "United States and Canada", "", "✓", "✓"],
    ["NVIDIA Corp.", "Semiconductors", "United States and Canada", "", "✓", "✓"],
    ["Oncor Electric Delivery Co. LLC", "Utilities", "United States and Canada", "", "✓", "✓"],
    ["Ontario Power Generation, Inc.", "Utilities", "United States and Canada", "", "✓", "✓"],
    ["Opendoor Technologies, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Oracle Corp.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["O'Reilly Automotive, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["Osisko Gold Royalties Ltd.", "Precious Metals", "United States and Canada", "", "✓", "✓"],
    ["Otis Worldwide Corp.", "Machinery", "United States and Canada", "", "", "✓"],
    ["Palo Alto Networks, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Parex Resources, Inc.", "Oil & Gas Producers", "United States and Canada", "", "", "✓"],
    ["Pembina Pipeline Corp.", "Refiners & Pipelines", "United States and Canada", "", "", "✓"],
    ["Penske Automotive Group, Inc.", "Retailing", "United States and Canada", "", "✓", ""],
    ["PepsiCo, Inc.", "Food Products", "United States and Canada", "", "", "✓"],
    ["Pfizer Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Polaris Inc.", "Consumer Durables", "United States and Canada", "", "✓", ""],
    ["Pool Corp.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["PrairieSky Royalty Ltd.", "Oil & Gas Producers", "United States and Canada", "✓", "✓", "✓"],
    ["Principal Financial Group, Inc.", "Insurance", "United States and Canada", "", "", "✓"],
    ["Prologis, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Public Storage", "Real Estate", "United States and Canada", "", "✓", ""],
    ["QUALCOMM, Inc.", "Semiconductors", "United States and Canada", "", "", "✓"],
    ["Rayonier, Inc.", "Real Estate", "United States and Canada", "", "✓", "✓"],
    ["Recursion Pharmaceuticals, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Regency Centers Corp.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Regeneron Pharmaceuticals, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Repligen Corp.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Revvity, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Rexford Industrial Realty, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["RioCan Real Estate Investment Trust", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Robert Half, Inc.", "Commercial Services", "United States and Canada", "", "✓", ""],
    ["Royal Gold, Inc.", "Precious Metals", "United States and Canada", "", "✓", "✓"],
    ["Ryder System, Inc.", "Transportation", "United States and Canada", "", "", "✓"],
    ["Salesforce, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Sandstorm Gold Ltd.", "Precious Metals", "United States and Canada", "", "✓", "✓"],
    ["SBA Communications Corp.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Seagate Technology Holdings Plc", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Sensata Technologies Holding Plc", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Simon Property Group, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["SL Green Realty Corp.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Spin Master Corp.", "Consumer Durables", "United States and Canada", "", "✓", "✓"],
    ["Stantec, Inc.", "Construction & Engineering", "United States and Canada", "", "", "✓"],
    ["Starwood Property Trust, Inc.", "Real Estate", "United States and Canada", "", "✓", "✓"],
    ["Sun Life Financial, Inc.", "Insurance", "United States and Canada", "", "", "✓"],
    ["Synopsys, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Take-Two Interactive Software, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["TD SYNNEX Corp.", "Technology Hardware", "United States and Canada", "", "✓", "✓"],
    ["Teck Resources Limited", "Diversified Metals", "United States and Canada", "", "", "✓"],
    ["TELUS International (CDA), Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["Texas Pacific Land Corp.", "Oil & Gas Producers", "United States and Canada", "", "✓", "✓"],
    ["The Cigna Group", "Healthcare", "United States and Canada", "", "", "✓"],
    ["The Descartes Systems Group, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["The Hershey Co.", "Food Products", "United States and Canada", "", "", "✓"],
    ["The Home Depot, Inc.", "Retailing", "United States and Canada", "", "✓", ""],
    ["The New York Times Co.", "Media", "United States and Canada", "", "✓", "✓"],
    ["The Western Union Co.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["The Williams Cos., Inc.", "Refiners & Pipelines", "United States and Canada", "", "", "✓"],
    ["Thermo Fisher Scientific, Inc.", "Pharmaceuticals", "United States and Canada", "", "✓", "✓"],
    ["Topaz Energy Corp.", "Oil & Gas Producers", "United States and Canada", "", "✓", "✓"],
    ["Trimble, Inc.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Triple Flag Precious Metals Corp.", "Precious Metals", "United States and Canada", "", "✓", "✓"],
    ["Udemy, Inc.", "Software & Services", "United States and Canada", "", "", "✓"],
    ["UnitedHealth Group, Inc.", "Healthcare", "United States and Canada", "", "", "✓"],
    ["Universal Display Corp.", "Technology Hardware", "United States and Canada", "✓", "✓", "✓"],
    ["US Foods Holding Corp.", "Food Retailers", "United States and Canada", "", "✓", "✓"],
    ["Valvoline, Inc.", "Chemicals", "United States and Canada", "", "", "✓"],
    ["Ventas, Inc.", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Vontier Corp.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["W.W. Grainger, Inc.", "Traders & Distributors", "United States and Canada", "", "", "✓"],
    ["Waters Corp.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Welltower OP LLC", "Real Estate", "United States and Canada", "", "✓", ""],
    ["Western Digital Corp.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Wheaton Precious Metals Corp.", "Precious Metals", "United States and Canada", "✓", "✓", "✓"],
    ["Williams-Sonoma, Inc.", "Retailing", "United States and Canada", "", "✓", "✓"],
    ["Windstream Services LLC", "Telecommunication Services", "United States and Canada", "", "✓", "✓"],
    ["WSP Global, Inc.", "Construction & Engineering", "United States and Canada", "", "", "✓"],
    ["Xylem, Inc.", "Machinery", "United States and Canada", "", "", "✓"],
    ["YETI Holdings, Inc.", "Consumer Durables", "United States and Canada", "", "✓", ""],
    ["Zebra Technologies Corp.", "Technology Hardware", "United States and Canada", "", "✓", ""],
    ["Zoetis, Inc.", "Pharmaceuticals", "United States and Canada", "", "", "✓"],
    ["Zurn Elkay Water Solutions Corp.", "Building Products", "United States and Canada", "", "✓", "✓"],
]

# %%
# 데이터를 DataFrame으로 변환
df = pd.DataFrame(data, columns=["Company", "Industry Group", "Region", "Global Top 50", "Region Top Rated", "Industry Top Rated"])

# %%
df.to_csv('sustainalytics_corporate.csv', index=False)

# %%
corporate = pd.read_csv('sustainalytics_corporate.csv')

# %%
corporate.to_excel('sustainalytics_corporate.xlsx')
